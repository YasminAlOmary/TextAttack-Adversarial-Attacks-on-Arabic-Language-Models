# %% [markdown]
# https://textattack.readthedocs.io/en/latest/api/datasets.html#textattack.datasets.Dataset

# %%
# !pip install textattack
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 38.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.7/445.7 kB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 37.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##  Example of sentiment-classification dataset

# %%
import textattack

# Example of sentiment-classification dataset
data = [("I enjoyed the movie a lot!", 1),
        ("Absolutely horrible film.", 0),
        ("Our family had a fun time!", 1)]

dataset = textattack.datasets.Dataset(data)
print(dataset[1:2])  # Accessing the second element of the dataset
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [(OrderedDict([('text', 'Absolutely horrible film.')]), 0)]

# %% [markdown]
# ## Creating and Printing a Custom TextAttack Dataset

# %%
# Example for pair of sequence inputs (e.g., SNLI)
data = [("A man inspects the uniform of a figure in some East Asian country.", "The man is sleeping", 1)]
dataset = textattack.datasets.Dataset(data, input_columns=("premise", "hypothesis"))
print(dataset)

# %%
# Example for seq2seq
data = [("J'aime le film.", "I love the movie.")]
dataset = textattack.datasets.Dataset(data, input_columns=("input_text", "output_text"))
print(dataset)

# %%
import textattack

# Example of sentiment-classification dataset sst2
data = [("A very well-made, funny movie.", 1),
        ("This film was just a waste of time.", 0),
        ("An amazing movie experience!", 1)]

dataset = textattack.datasets.Dataset(data)
print(dataset[:])  # Accessing the second element of the dataset
# Out:
# [(OrderedDict([('text', 'A very well-made, funny movie.')]), 1), (OrderedDict([('text', 'This film was just a waste of time.')]), 0), (OrderedDict([('text', 'An amazing movie experience!')]), 1)]

# %%
# Load the uploaded file to inspect its structure
import pandas as pd

file_path = '/content/sst2_sample_10.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#                                            text  label
# 0                A very well-made, funny movie.      1
# 1           This film was just a waste of time.      0
# 2                  An amazing movie experience!      1
# 3  The plot was terrible and acting even worse.      0
# 4                    A must-watch for all ages.      1

# %% [markdown]
# ## Running DeepWordBug Adversarial Attack on Custom Dataset (sst2_sample_10) Using DistilBERT SST-2 Model

# %%
# !textattack attack --model-from-huggingface distilbert-base-uncased-finetuned-sst-2-english --dataset-from-file custom_dataset.py --recipe deepwordbug --num-examples 5
# Out:
# 2024-12-18 13:56:15.519107: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 13:56:15.554700: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 13:56:15.565256: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 13:56:17.265321: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading model and tokenizer from file: None
# textattack: Loading module from `custom_dataset.py`.
# ...

# %% [markdown]
# ## Running DeepWordBug Adversarial Attack on Custom Dataset (nlpdataset_processed) Using DistilBERT SST-2 Model

# %%
# Load the uploaded file to inspect its structure
import pandas as pd

file_path = '/content/nlpdataset.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    ID                                      Text     label
# 0   1        I love this product! It's amazing.  Positive
# 1   2         The movie was okay, not the best.   Neutral
# 2   3  I am very disappointed with the service.  Negative
# 3   4          Absolutely fantastic experience!  Positive
# 4   5                      Not worth the price.  Negative

# %%
# !textattack attack --model-from-huggingface distilbert-base-uncased-finetuned-sst-2-english --dataset-from-file nlpdataset_processed.py --recipe deepwordbug --num-examples 4
# Out:
# 2024-12-18 14:44:44.281489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 14:44:44.313782: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 14:44:44.323424: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 14:44:45.980647: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading model and tokenizer from file: None
# textattack: Loading module from `nlpdataset_processed.py`.
# ...
